# %% [markdown]
# <a href="https://colab.research.google.com/github/number1coder01/Machine-Learning/blob/main/Lecture29Pipelining(b).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive # now this can behave as a webpage jaha user apna data deta hai
drive.mount('/content/drive')

# THESE STEPS ARE A CUMMULATION OF ALL THE TOPICS TAUGHT PREVIOUSLY
# Out:
# Mounted at /content/drive

# %%
import pickle
# decoding the ml mdoel
ohe_sex = pickle.load(open('/content/drive/MyDrive/models/ohe_sex.pkl', 'rb'))
ohe_embarked = pickle.load(open('/content/drive/MyDrive/models/ohe_embarked.pkl', 'rb'))
clf = pickle.load(open('/content/drive/MyDrive/models/clf.pkl', 'rb'))

# %%
# Assume user input
# Pclass/gender/age/SibSp/Parch/Fare/Embarked
import numpy as np
test_input = np.array([2, 'male', 31.0, 0, 0, 10.5, 'S'],dtype=object).reshape(1,7)

# %%
test_input
# Out:
# array([[2, 'male', 31.0, 0, 0, 10.5, 'S']], dtype=object)

# %%
test_input_sex = ohe_sex.transform(test_input[:,1].reshape(1,1))
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(

# %%
test_input_sex
# Out:
# array([[0., 1.]])

# %%
test_input_embarked = ohe_embarked.transform(test_input[:,-1].reshape(1,1))

# %%
test_input_embarked
# Out:
# array([[0., 0., 1.]])

# %%
test_input_age = test_input[:,2].reshape(1,1)

# %%
test_input_transformed = np.concatenate((test_input[:,[0,3,4,5]],test_input_age,test_input_sex,test_input_embarked),axis=1)
test_input_transformed.shape
# Out:
# (1, 10)

# %%
clf.predict(test_input_transformed)
# Out:
# array([0])
