# %% [markdown]
# <a href="https://colab.research.google.com/github/number1coder01/Machine-Learning/blob/main/Numpy2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Numpy Array Attributes

# %%
import numpy as np
a1 = np.arange(10)
a2 = np.arange(12 , dtype = float).reshape(3,4)
a3 = np.arange(40).reshape(2,4,5)
a4 = np.arange(10 , dtype = np.int32)

# %%
# No. of dimensions
a3.ndim
# Out:
# 3

# %%
# Har dimension mei kitne items(distribution)
a3.shape # 2 2D arrays of shape 4,5 => no. of arrays , rows*cols
# Out:
# (2, 4, 5)

# %%
# Total Number of Items
a3.size
# Out:
# 40

# %%
# Har item memory mei kitna size le raha hai
print(a3.itemsize)
print(a4.itemsize)
# Out:
# 8
# 4

# %%
# Items ka datatype
print(a2.dtype)
# Out:
# float64
